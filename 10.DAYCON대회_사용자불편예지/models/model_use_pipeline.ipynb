# %%
from pycaret.classification import *
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
from tqdm import tqdm
import gc
import random
import lightgbm as lgb
import re
from sklearn.metrics import *
from sklearn.model_selection import KFold
import warnings
warnings.filterwarnings(action='ignore')

# %%
train = pd.read_csv(r'C:\Users\gmlkd\machine-learning-exercises\10.DAYCON대회_사용자불편예지\training set\train_case2.csv')
train_problem = pd.read_csv(r'C:\Users\gmlkd\machine-learning-exercises\10.DAYCON대회_사용자불편예지\preprocessed data\new_train_problem.csv', parse_dates=['time'])
test = pd.read_csv(r'C:\Users\gmlkd\machine-learning-exercises\10.DAYCON대회_사용자불편예지\training set\test_case2.csv')
submission = pd.read_csv("C:/Users/gmlkd/data/시스템 품질 변화로 인한 사용자 불편 예지 AI 경진대회_data/sample_submission.csv")

# %%
train = train.to_numpy()
problem = np.zeros(15000)
problem[train_problem.user_id.unique() - 10000] = 1

train_x = train
train_y = problem

# %%
# Train
#-------------------------------------------------------------------------------------
# validation auc score를 확인하기 위해 정의
def f_pr_auc(probas_pred, y_true):
    labels=y_true.get_label()
    p, r, _ = precision_recall_curve(labels, probas_pred)
    score=auc(r,p) 
    return "pr_auc", score, True
#-------------------------------------------------------------------------------------
models     = []
recalls    = []
precisions = []
auc_scores   = []
threshold = 0.5
# 파라미터 설정
params =      {
                'boosting_type' : 'gbdt',
                'objective'     : 'binary',
                'metric'        : 'auc',
                'seed': 1015
                }
#-------------------------------------------------------------------------------------
# 5 Kfold cross validation
k_fold = KFold(n_splits=5, shuffle=True, random_state=42)
for train_idx, val_idx in k_fold.split(train_x):
    # split train, validation set
    X = train_x[train_idx]
    y = train_y[train_idx]
    valid_x = train_x[val_idx]
    valid_y = train_y[val_idx]

    d_train= lgb.Dataset(X, y)
    d_val  = lgb.Dataset(valid_x, valid_y)
    
    #run traning
    model = lgb.train(
                        params,
                        train_set       = d_train,
                        num_boost_round = 1000,
                        valid_sets      = d_val,
                        feval           = f_pr_auc,
                        verbose_eval    = 20, 
                        early_stopping_rounds = 3
                       )
    
    # cal valid prediction
    valid_prob = model.predict(valid_x)
    valid_pred = np.where(valid_prob > threshold, 1, 0)
    
    # cal scores
    recall    = recall_score(    valid_y, valid_pred)
    precision = precision_score( valid_y, valid_pred)
    auc_score = roc_auc_score(   valid_y, valid_prob)

    # append scores
    models.append(model)
    recalls.append(recall)
    precisions.append(precision)
    auc_scores.append(auc_score)

    print('==========================================================')
# Out:
# [LightGBM] [Info] Number of positive: 3633, number of negative: 8367
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002209 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5879
# [LightGBM] [Info] Number of data points in the train set: 12000, number of used features: 58
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.302750 -> initscore=-0.834237
# [LightGBM] [Info] Start training from score -0.834237
# Training until validation scores don't improve for 3 rounds
# Early stopping, best iteration is:
# [2]	valid_0's auc: 0.796928	valid_0's pr_auc: 0.803588
# ==========================================================
# [LightGBM] [Info] Number of positive: 4828, number of negative: 7172
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002251 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6078
# [LightGBM] [Info] Number of data points in the train set: 12000, number of used features: 58
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.402333 -> initscore=-0.395752
# [LightGBM] [Info] Start training from score -0.395752
# Training until validation scores don't improve for 3 rounds
# Early stopping, best iteration is:
# [1]	valid_0's auc: 0.786583	valid_0's pr_auc: 0.322539
# ==========================================================
# [LightGBM] [Info] Number of positive: 4718, number of negative: 7282
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002210 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6083
# [LightGBM] [Info] Number of data points in the train set: 12000, number of used features: 58
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.393167 -> initscore=-0.434021
# [LightGBM] [Info] Start training from score -0.434021
# Training until validation scores don't improve for 3 rounds
# Early stopping, best iteration is:
# [11]	valid_0's auc: 0.790376	valid_0's pr_auc: 0.450813
# ==========================================================
# [LightGBM] [Info] Number of positive: 4544, number of negative: 7456
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002310 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6080
# [LightGBM] [Info] Number of data points in the train set: 12000, number of used features: 58
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.378667 -> initscore=-0.495211
# [LightGBM] [Info] Start training from score -0.495211
# Training until validation scores don't improve for 3 rounds
# Early stopping, best iteration is:
# [5]	valid_0's auc: 0.809069	valid_0's pr_auc: 0.550402
# ==========================================================
# [LightGBM] [Info] Number of positive: 2277, number of negative: 9723
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001782 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5773
# [LightGBM] [Info] Number of data points in the train set: 12000, number of used features: 58
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.189750 -> initscore=-1.451635
# [LightGBM] [Info] Start training from score -1.451635
# Training until validation scores don't improve for 3 rounds
# [20]	valid_0's auc: 0.813225	valid_0's pr_auc: 0.976405
# Early stopping, best iteration is:
# [17]	valid_0's auc: 0.81382	valid_0's pr_auc: 0.976324
# ==========================================================

# %%
print(np.mean(auc_scores))
# Out:
# 0.7993551366349869

# %%
train_x = pd.DataFrame(train_x)
train_y = pd.DataFrame(train_y)
train_y.columns = ['problem']
train = pd.concat([train_x,train_y], axis =1)
train
# Out:
#               0         1         2         3         4         5         6  \
# 0     -0.268744 -0.340504 -0.239957 -0.414143  0.102027 -0.055185 -0.047764
# 1      0.500848 -0.340504 -0.239957  4.011349 -0.064861 -0.055185 -0.047764
# 2     -0.272916 -0.340504 -0.239957 -0.414143  0.096218 -0.055185 -0.047764
# 3     -0.275951 -0.340504 -0.239957  0.146356 -0.064861 -0.055185 -0.047764
# 4     -0.093888  0.651704 -0.239957 -0.414143 -0.064861 -0.055185 -0.047764
# ...         ...       ...       ...       ...       ...       ...       ...
# 14
#             70        71   72   73  problem
# 0     -0.06688  0.442781  0.0  0.0      0.0
# 1     -0.06688  0.442781  0.0  1.0      1.0
# 2     -0.06688  0.272376  0.0  0.0      0.0
# 3     -0.06688  0.442781  0.0  1.0      0.0
# 4     -0.06688  0.442781  0.0  1.0      1.0
# ...        ...       ...  ...  ...      ...
# 14995 -0.06688 -2.965326  0.0  0.0      0.0
# 14996 -0.06688 -4.498974  0.0  0.0      0.0
# 14997 -0.06688  0.442781  0.0  1.0      1.0
# 14998 -0.06688 -1.090867  0.0  1.0      1.0
# 14999 -0.06688  0.442781  0.0  0.0      0.0
#
# [15000 rows x 75 columns]

# %%
clf = setup(data = train, target = "problem", silent=True, session_id=42, train_size=0.85)
# Out:
# <style type="text/css">
# #T_50a10_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_50a10">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50a10_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_50a10_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50a10_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_50a10_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_50a10_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_50a10_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_50a10_row1_col1" class="data row1 col1" >problem</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_50a10_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_50a10_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_50a10_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_50a10_row3_col1" class="data row3 col1" >0.0: 0, 1.0: 1</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_50a10_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_50a10_row4_col1" class="data row4 col1" >(15000, 75)</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_50a10_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_50a10_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_50a10_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_50a10_row6_col1" class="data row6 col1" >67</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_50a10_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_50a10_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_50a10_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_50a10_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_50a10_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_50a10_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_50a10_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_50a10_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_50a10_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_50a10_row11_col1" class="data row11 col1" >(12749, 74)</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_50a10_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_50a10_row12_col1" class="data row12 col1" >(2251, 74)</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_50a10_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_50a10_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_50a10_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_50a10_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_50a10_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_50a10_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_50a10_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_50a10_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_50a10_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_50a10_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_50a10_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_50a10_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_50a10_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_50a10_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_50a10_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_50a10_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_50a10_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_50a10_row21_col1" class="data row21 col1" >7e0a</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_50a10_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_50a10_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_50a10_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_50a10_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_50a10_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_50a10_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_50a10_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_50a10_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_50a10_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_50a10_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_50a10_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_50a10_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_50a10_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_50a10_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_50a10_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_50a10_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_50a10_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_50a10_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_50a10_row30_

# %%
best_3 = compare_models(sort = 'AUC', n_select = 3)
# Out:
# <style type="text/css">
# #T_efad6 th {
#   text-align: left;
# }
# #T_efad6_row0_col0, #T_efad6_row0_col1, #T_efad6_row0_col3, #T_efad6_row0_col4, #T_efad6_row0_col5, #T_efad6_row0_col6, #T_efad6_row0_col7, #T_efad6_row1_col0, #T_efad6_row1_col2, #T_efad6_row1_col3, #T_efad6_row1_col4, #T_efad6_row2_col0, #T_efad6_row2_col1, #T_efad6_row2_col2, #T_efad6_row2_col3, #T_efad6_row2_col4, #T_efad6_row2_col5, #T_efad6_row2_col6, #T_efad6_row2_col7, #T_efad6_row3_col0, #T_efad6_row3_col1, #T_efad6_row3_col2, #T_efad6_row3_col3, #T_efad6_row3_col4, #T_efad6_row3_col5, #T_efad6_row3_col6, #T_efad6_row3_col7, #T_efad6_row4_col0, #T_efad6_row4_col1, #T_efad6_row4_col2, #T_efad6_row4_col3, #T_efad6_row4_col4, #T_efad6_row4_col5, #T_efad6_row4_col6, #T_efad6_row4_col7, #T_efad6_row5_col0, #T_efad6_row5_col1, #T_efad6_row5_col2, #T_efad6_row5_col3, #T_efad6_row5_col4, #T_efad6_row5_col5, #T_efad6_row5_col6, #T_efad6_row5_col7, #T_efad6_row6_col0, #T_efad6_row6_col1, #T_efad6_row6_col2, #T_efad6_row6_col3, #T_efad6_row6_col4, #T_efad6_row6_col5, #T_efad6_row6_col6, #T_efad6_row6_col7, #T_efad6_row7_col0, #T_efad6_row7_col1, #T_efad6_row7_col2, #T_efad6_row7_col4, #T_efad6_row7_col5, #T_efad6_row7_col6, #T_efad6_row7_col7, #T_efad6_row8_col0, #T_efad6_row8_col1, #T_efad6_row8_col2, #T_efad6_row8_col3, #T_efad6_row8_col4, #T_efad6_row8_col5, #T_efad6_row8_col6, #T_efad6_row8_col7, #T_efad6_row9_col0, #T_efad6_row9_col1, #T_efad6_row9_col2, #T_efad6_row9_col3, #T_efad6_row9_col4, #T_efad6_row9_col5, #T_efad6_row9_col6, #T_efad6_row9_col7, #T_efad6_row10_col0, #T_efad6_row10_col1, #T_efad6_row10_col2, #T_efad6_row10_col3, #T_efad6_row10_col4, #T_efad6_row10_col5, #T_efad6_row10_col6, #T_efad6_row10_col7, #T_efad6_row11_col0, #T_efad6_row11_col1, #T_efad6_row11_col2, #T_efad6_row11_col3, #T_efad6_row11_col4, #T_efad6_row11_col5, #T_efad6_row11_col6, #T_efad6_row11_col7, #T_efad6_row12_col0, #T_efad6_row12_col1, #T_efad6_row12_col2, #T_efad6_row12_col3, #T_efad6_row12_col4, #T_efad6_row12_col5, #T_efad6_row12_col6, #T_efad6_row12_col7, #T_efad6_row13_col0, #T_efad6_row13_col1, #T_efad6_row13_col2, #T_efad6_row13_col3, #T_efad6_row13_col5, #T_efad6_row13_col6, #T_efad6_row13_col7 {
#   text-align: left;
# }
# #T_efad6_row0_col2, #T_efad6_row1_col1, #T_efad6_row1_col5, #T_efad6_row1_col6, #T_efad6_row1_col7, #T_efad6_row7_col3, #T_efad6_row13_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_efad6_row0_col8, #T_efad6_row1_col8, #T_efad6_row2_col8, #T_efad6_row3_col8, #T_efad6_row4_col8, #T_efad6_row5_col8, #T_efad6_row6_col8, #T_efad6_row7_col8, #T_efad6_row8_col8, #T_efad6_row9_col8, #T_efad6_row10_col8, #T_efad6_row12_col8, #T_efad6_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_efad6_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_efad6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efad6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_efad6_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_efad6_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_efad6_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_efad6_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_efad6_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_efad6_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_efad6_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_efad6_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efad6_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_efad6_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_efad6_row0_col1" class="data row0 col1" >0.8147</td>
#       <td id="T_efad6_row0_col2" class="data row0 col2" >0.8148</td>
#       <td id="T_efad6_row0_col3" class="data row0 col3" >0.4593</td>
#       <td id="T_efad6_row0_col4" class="data row0 col4" >0.8175</td>
#       <td id="T_efad6_row0_col5" class="data row0 col5" >0.5878</td>
#       <td id="T_efad6_row0_col6" class="data row0 col6" >0.4803</td>
#       <td id="T_efad6_row0_col7" class="data row0 col7" >0.5137</td>
#       <td id="T_efad6_row0_col8" class="data row0 col8" >0.3790</td>
#     </tr>
#     <tr>
#       <th id="T_efad6_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_efad6_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_efad6_row1_col1" class="data row1 col1" >0.8166</td>
#       <td id="T_efad6_row1_col2" class="data row1 col2" >0.8143</td>
#       <td id="T_efad6_row1_col3" class="data row1 col3" >0.4947</td>
#       <td id="T_efad6_row1_col4" class="data row1 col4" >0.7903</td>
#       <td id="T_efad6_row1_col5" class="data row1 col5" >0.6083</td>
#       <td id="T_efad6_row1_col6" class="data row1 col6" >0.4967</td>
#       <td id="T_efad6_row1_col7" class="data row1 col7" >0.5201</td>
#       <td id="T_efad6_row1_col8" class="data row1 col8" >0.0570</td>
#     </tr>
#     <tr>
#       <th id="T_efad6_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_efad6_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_efad6_row2_col1" class="data row2 col1" >0.8148</td>
#       <td id="T_efad6_row2_col2" class="data row2 col2" >0.8100</td>
#       <td id="T_efad6_row2_col3" class="data row2 col3" >0.4724</td>
#       <td id="T_efad6_row2_col4" class="data row2 col4" >0.8039</td>
#       <td id="T_efad6_row2_col5" class="data row2 col5" >0.5948</td>
#       <td id="T_efad6_row2_col6" class="data row2 col6" >0.4851</td>
#       <td id="T_efad6_row2_col7" class="data row2 col7" >0.5141</td>
#       <td id="T_efad6_row2_col8" class="data row2 col8" >0.2170</td>
#     </tr>
#     <tr>
#       <th id="T_efad6_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_efad6_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_efad6_row3_col1" class="data row3 col1" >0.8085</td>
#       <td id="T_efad6_row3_col2" class="data row3 col2" >0.8057</td>
#       <td id="T_efad6_row3_col3" class="data row3 col3" >0.4615</td>
#       <td id="T_efad6_row3_col4" class="data row3 col4" >0.7852</td>
#       <td id="T_efad6_row3_col5" class="data row3 col5" >0.5811</td>
#       <td id="T_efad6_row3_col6" class="data row3 col6" >0.4677</td>
#       <td id="T_efad6_row3_col7" class="data row3 col7" >0.4956</td>
#       <td id="T_efad6_row3_col8" class="data row3 col8" >0.0990</td>
#     </tr>
#     <tr>
#       <th id="T_efad6_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_efad6_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_efad6_row4_col1" class="data row4 col1" >0.8130</td>
#       <td id="T_efad6_row4_col2" class="data row4 col2" >0.8051</td>
#       <td id="T_efad6_row4_col3" class="data row4 col3" >0.4691</td>
#       <td id="T_efad6_row4_col4" class="data row4 col4" >0.7991</td>
#       <td id="T_efad6_row4_col5" class="data row4 col5" >0.5907</td>
#       <td id="T_efad6_row4_col6" class="data row4 col6" >0.4801</td>
#       <td id="T_efad6_row4_col7" class="data row4 col7" >0.5089</td>
#       <td id="T_efad6_row4_col8" class="data row4 col8" >0.2170</td>
#     </tr>
#     <tr>
#       <th id="T_efad6_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_efad6_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_efad6_row5_col1" class="data row5 col1" >0.8048</td>
#       <td id="T_efad6_row5_col2" class="data row5 col2" >0.7775</td>
#       <td id="T_efad6_row5_col3" class="data row5 col3" >0.4119</td>
#       <td id="T_efad6_row5_col4" class="data row5 col4" >0.8213</td>
#       <td id="T_efad6_row5_col5" class="data row5 col5" >0.5483</td>
#       <td id="T_efad6_row5_col6" class="data row5 col6" >0.4409</td>
#       <td id="T_efad6_row5_col7" class="data row5 col7" >0.4837</td>

# %%
blended = blend_models(estimator_list = best_3, fold = 5, method = 'soft')
# Out:
# <style type="text/css">
# #T_e988b_row5_col0, #T_e988b_row5_col1, #T_e988b_row5_col2, #T_e988b_row5_col3, #T_e988b_row5_col4, #T_e988b_row5_col5, #T_e988b_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_e988b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e988b_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_e988b_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_e988b_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_e988b_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_e988b_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_e988b_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_e988b_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e988b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e988b_row0_col0" class="data row0 col0" >0.8137</td>
#       <td id="T_e988b_row0_col1" class="data row0 col1" >0.8057</td>
#       <td id="T_e988b_row0_col2" class="data row0 col2" >0.4632</td>
#       <td id="T_e988b_row0_col3" class="data row0 col3" >0.8076</td>
#       <td id="T_e988b_row0_col4" class="data row0 col4" >0.5887</td>
#       <td id="T_e988b_row0_col5" class="data row0 col5" >0.4795</td>
#       <td id="T_e988b_row0_col6" class="data row0 col6" >0.5105</td>
#     </tr>
#     <tr>
#       <th id="T_e988b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e988b_row1_col0" class="data row1 col0" >0.8239</td>
#       <td id="T_e988b_row1_col1" class="data row1 col1" >0.8249</td>
#       <td id="T_e988b_row1_col2" class="data row1 col2" >0.5027</td>
#       <td id="T_e988b_row1_col3" class="data row1 col3" >0.8146</td>
#       <td id="T_e988b_row1_col4" class="data row1 col4" >0.6217</td>
#       <td id="T_e988b_row1_col5" class="data row1 col5" >0.5152</td>
#       <td id="T_e988b_row1_col6" class="data row1 col6" >0.5407</td>
#     </tr>
#     <tr>
#       <th id="T_e988b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e988b_row2_col0" class="data row2 col0" >0.8173</td>
#       <td id="T_e988b_row2_col1" class="data row2 col1" >0.8108</td>
#       <td id="T_e988b_row2_col2" class="data row2 col2" >0.4578</td>
#       <td id="T_e988b_row2_col3" class="data row2 col3" >0.8317</td>
#       <td id="T_e988b_row2_col4" class="data row2 col4" >0.5905</td>
#       <td id="T_e988b_row2_col5" class="data row2 col5" >0.4853</td>
#       <td id="T_e988b_row2_col6" class="data row2 col6" >0.5212</td>
#     </tr>
#     <tr>
#       <th id="T_e988b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e988b_row3_col0" class="data row3 col0" >0.8149</td>
#       <td id="T_e988b_row3_col1" class="data row3 col1" >0.8144</td>
#       <td id="T_e988b_row3_col2" class="data row3 col2" >0.4776</td>
#       <td id="T_e988b_row3_col3" class="data row3 col3" >0.7995</td>
#       <td id="T_e988b_row3_col4" class="data row3 col4" >0.5980</td>
#       <td id="T_e988b_row3_col5" class="data row3 col5" >0.4875</td>
#       <td id="T_e988b_row3_col6" class="data row3 col6" >0.5148</td>
#     </tr>
#     <tr>
#       <th id="T_e988b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e988b_row4_col0" class="data row4 col0" >0.8140</td>
#       <td id="T_e988b_row4_col1" class="data row4 col1" >0.8336</td>
#       <td id="T_e988b_row4_col2" class="data row4 col2" >0.4564</td>
#       <td id="T_e988b_row4_col3" class="data row4 col3" >0.8171</td>
#       <td id="T_e988b_row4_col4" class="data row4 col4" >0.5857</td>
#       <td id="T_e988b_row4_col5" class="data row4 col5" >0.4779</td>
#       <td id="T_e988b_row4_col6" class="data row4 col6" >0.5116</td>
#     </tr>
#     <tr>
#       <th id="T_e988b_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_e988b_row5_col0" class="data row5 col0" >0.8168</td>
#       <td id="T_e988b_row5_col1" class="data row5 col1" >0.8179</td>
#       <td id="T_e988b_row5_col2" class="data row5 col2" >0.4715</td>
#       <td id="T_e988b_row5_col3" class="data row5 col3" >0.8141</td>
#       <td id="T_e988b_row5_col4" class="data row5 col4" >0.5969</td>
#       <td id="T_e988b_row5_col5" class="data row5 col5" >0.4891</td>
#       <td id="T_e988b_row5_col6" class="data row5 col6" >0.5198</td>
#     </tr>
#     <tr>
#       <th id="T_e988b_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_e988b_row6_col0" class="data row6 col0" >0.0038</td>
#       <td id="T_e988b_row6_col1" class="data row6 col1" >0.0101</td>
#       <td id="T_e988b_row6_col2" class="data row6 col2" >0.0173</td>
#       <td id="T_e988b_row6_col3" class="data row6 col3" >0.0107</td>
#       <td id="T_e988b_row6_col4" class="data row6 col4" >0.0130</td>
#       <td id="T_e988b_row6_col5" class="data row6 col5" >0.0135</td>
#       <td id="T_e988b_row6_col6" class="data row6 col6" >0.0111</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout = predict_model(blended)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1107b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1107b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1107b_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1107b_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1107b_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1107b_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1107b_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1107b_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1107b_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1107b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1107b_row0_col0" class="data row0 col0" >Voting Classifier</td>
#       <td id="T_1107b_row0_col1" class="data row0 col1" >0.6726</td>
#       <td id="T_1107b_row0_col2" class="data row0 col2" >0.8206</td>
#       <td id="T_1107b_row0_col3" class="data row0 col3" >0.4740</td>
#       <td id="T_1107b_row0_col4" class="data row0 col4" >0.9431</td>
#       <td id="T_1107b_row0_col5" class="data row0 col5" >0.6309</td>
#       <td id="T_1107b_row0_col6" class="data row0 col6" >0.3900</td>
#       <td id="T_1107b_row0_col7" class="data row0 col7" >0.4659</td>
#     </tr>
#   </tbody>
# </table>

# %%
final_model = finalize_model(blended)

# %%
# pycaret의 predict_model을 사용하기 위해 test의 모든 컬럼을 정수로 변경
t_columns = list(np.arange(0,74))
test.columns = t_columns

# %%
prep_pipe = get_config('prep_pipe')
transformed_unseen_data = prep_pipe.transform(test)

# %%
prections = final_model.predict_proba(transformed_unseen_data)[:,1]
prections
# Out:
# array([0.91528047, 0.37724455, 0.45742957, ..., 0.66312932, 0.87929147,
#        0.51487411])

# %%
a = prections[:43262-30000]
b = prections[43262-30000:]

# %%
new = prections.mean()
new
# Out:
# 0.4944148152602951

# %%
a = np.append(a, new)
print(a)
print(b)
# Out:
# [0.91528047 0.37724455 0.45742957 ... 0.44824058 0.35992413 0.49441482]
# [0.34965652 0.3971697  0.35079405 ... 0.66312932 0.87929147 0.51487411]

# %%
prections = np.concatenate((a, b))
prections
# Out:
# array([0.91528047, 0.37724455, 0.45742957, ..., 0.66312932, 0.87929147,
#        0.51487411])

# %%
submission['problem'] = prections
submission
# Out:
#        user_id   problem
# 0        30000  0.915280
# 1        30001  0.377245
# 2        30002  0.457430
# 3        30003  0.841255
# 4        30004  0.823994
# ...        ...       ...
# 14994    44994  0.432040
# 14995    44995  0.495195
# 14996    44996  0.663129
# 14997    44997  0.879291
# 14998    44998  0.514874
#
# [14999 rows x 2 columns]

# %%
submission.iloc[43262-30000]
# Out:
# user_id    43262.000000
# problem        0.494415
# Name: 13262, dtype: float64

# %%
submission.to_csv(r'C:\Users\gmlkd\machine-learning-exercises\10.DAYCON대회_사용자불편예지\submissions\submission_use_pipeline.csv', index=False)
